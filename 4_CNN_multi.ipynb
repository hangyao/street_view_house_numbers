# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

pickle_file = 'SVHN_multi.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (230070, 32, 32, 1) (230070, 6)
# Validation set (5684, 32, 32, 1) (5684, 6)
# Test set (13068, 32, 32, 1) (13068, 6)

# %%
def LecunLCN(X, image_shape, threshold=1e-4, radius=7, use_divisor=True):
    """Local Contrast Normalization"""
    """[http://yann.lecun.com/exdb/publis/pdf/jarrett-iccv-09.pdf]"""

    # Get Gaussian filter
    filter_shape = (radius, radius, image_shape[3], 1)

    #self.filters = theano.shared(self.gaussian_filter(filter_shape), borrow=True)
    filters = gaussian_filter(filter_shape)
    X = tf.convert_to_tensor(X, dtype=tf.float32)
    # Compute the Guassian weighted average by means of convolution
    convout = tf.nn.conv2d(X, filters, [1,1,1,1], 'SAME')

    # Subtractive step
    mid = int(np.floor(filter_shape[1] / 2.))

    # Make filter dimension broadcastable and subtract
    centered_X = tf.sub(X, convout)

    # Boolean marks whether or not to perform divisive step
    if use_divisor:
        # Note that the local variances can be computed by using the centered_X
        # tensor. If we convolve this with the mean filter, that should give us
        # the variance at each point. We simply take the square root to get our
        # denominator

        # Compute variances
        sum_sqr_XX = tf.nn.conv2d(tf.square(centered_X), filters, [1,1,1,1], 'SAME')

        # Take square root to get local standard deviation
        denom = tf.sqrt(sum_sqr_XX)

        per_img_mean = tf.reduce_mean(denom)
        divisor = tf.maximum(per_img_mean, denom)
        # Divisise step
        new_X = tf.truediv(centered_X, tf.maximum(divisor, threshold))
    else:
        new_X = centered_X

    return new_X


def gaussian_filter(kernel_shape):
    x = np.zeros(kernel_shape, dtype = float)
    mid = np.floor(kernel_shape[0] / 2.)
    
    for kernel_idx in xrange(0, kernel_shape[2]):
        for i in xrange(0, kernel_shape[0]):
            for j in xrange(0, kernel_shape[1]):
                x[i, j, kernel_idx, 0] = gauss(i - mid, j - mid)
    
    return tf.convert_to_tensor(x / np.sum(x), dtype=tf.float32)

def gauss(x, y, sigma=3.0):
    Z = 2 * np.pi * sigma ** 2
    return  1. / Z * np.exp(-(x ** 2 + y ** 2) / (2. * sigma ** 2))

# %%
def accuracy(predictions, labels):

  return (100.0 * np.sum(np.argmax(predictions, 2).T == labels) / predictions.shape[1] / predictions.shape[0])

# %%
image_size = 32
num_labels = 11 # 0-9, + blank 
num_channels = 1 # grayscale

batch_size = 64
patch_size = 5
depth1 = 16
depth2 = 32
depth3 = 64
num_hidden1 = 64
#num_hidden2 = 16
shape = [batch_size, image_size, image_size, num_channels]

# Construct a 7-layer CNN.
# C1: convolutional layer, batch_size x 28 x 28 x 16, convolution size: 5 x 5 x 1 x 16
# S2: sub-sampling layer, batch_size x 14 x 14 x 16
# C3: convolutional layer, batch_size x 10 x 10 x 32, convolution size: 5 x 5 x 16 x 32
# S4: sub-sampling layer, batch_size x 5 x 5 x 32
# C5: convolutional layer, batch_size x 1 x 1 x 64, convolution size: 5 x 5 x 32 x 64
# Dropout
# F6: fully-connected layer, weight size: 64 x 16
# Output layer, weight size: 16 x 10

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.int32, shape=(batch_size, 6))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.get_variable("W1", shape=[patch_size, patch_size, num_channels, depth1],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
  layer1_biases = tf.Variable(tf.constant(1.0, shape=[depth1]), name='B1')
  layer2_weights = tf.get_variable("W2", shape=[patch_size, patch_size, depth1, depth2],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]), name='B2')
  layer3_weights = tf.get_variable("W3", shape=[patch_size, patch_size, depth2, num_hidden1],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden1]), name='B3')

  s1_w = tf.get_variable("WS1", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s1_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS1')
  s2_w = tf.get_variable("WS2", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s2_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS2')
  s3_w = tf.get_variable("WS3", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s3_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS3')
  s4_w = tf.get_variable("WS4", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s4_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS4')
  s5_w = tf.get_variable("WS5", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s5_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS5')
  
  # Model.
  def model(data, keep_prob, shape):
    LCN = LecunLCN(data, shape)
    conv = tf.nn.conv2d(LCN, layer1_weights, [1,1,1,1], 'VALID', name='C1')
    hidden = tf.nn.relu(conv + layer1_biases)
    lrn = tf.nn.local_response_normalization(hidden)
    sub = tf.nn.max_pool(lrn, [1,2,2,1], [1,2,2,1], 'SAME', name='S2')
    conv = tf.nn.conv2d(sub, layer2_weights, [1,1,1,1], padding='VALID', name='C3')
    hidden = tf.nn.relu(conv + layer2_biases)
    lrn = tf.nn.local_response_normalization(hidden)
    sub = tf.nn.max_pool(lrn, [1,2,2,1], [1,2,2,1], 'SAME', name='S4')
    conv = tf.nn.conv2d(sub, layer3_weights, [1,1,1,1], padding='VALID', name='C5')
    hidden = tf.nn.relu(conv + layer3_biases)
    hidden = tf.nn.dropout(hidden, keep_prob)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    #hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    logits1 = tf.matmul(reshape, s1_w) + s1_b
    logits2 = tf.matmul(reshape, s2_w) + s2_b
    logits3 = tf.matmul(reshape, s3_w) + s3_b
    logits4 = tf.matmul(reshape, s4_w) + s4_b
    logits5 = tf.matmul(reshape, s5_w) + s5_b
    return [logits1, logits2, logits3, logits4, logits5]
  
  # Training computation.
  [logits1, logits2, logits3, logits4, logits5] = model(tf_train_dataset, 0.9375, shape)
  loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits1, tf_train_labels[:,1])) +\
tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits2, tf_train_labels[:,2])) +\
tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits3, tf_train_labels[:,3])) +\
tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits4, tf_train_labels[:,4])) +\
tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits5, tf_train_labels[:,5]))
    
  # Optimizer.
  #optimizer = tf.train.AdagradOptimizer(0.01).minimize(loss)
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(0.05, global_step, 10000, 0.95)
  optimizer = tf.train.AdagradOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.pack([tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[0]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[1]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[2]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[3]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[4])])
  valid_prediction = tf.pack([tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[0]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[1]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[2]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[3]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[4])])
  test_prediction = tf.pack([tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[0]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[1]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[2]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[3]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[4])])
    
  saver = tf.train.Saver()

num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()  
  reader = tf.train.NewCheckpointReader("CNN_1.ckpt")
  reader.get_variable_to_shape_map()
  #saver.restore(session, "CNN_1.ckpt")
  print("Model restored.")  

  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size),:]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    
    if (step % 500 == 0): 
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels[:,1:6]))
      print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels[:,1:6]))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels[:,1:6]))
  save_path = saver.save(session, "CNN_multi.ckpt")
  print("Model saved in file: %s" % save_path)
# Out:
# Model restored.
# Initialized
# Minibatch loss at step 0: 17.044586
# Minibatch accuracy: 4.1%
# Validation accuracy: 57.2%
# Minibatch loss at step 500: 6.768282
# Minibatch accuracy: 55.6%
# Validation accuracy: 57.5%
# Minibatch loss at step 1000: 6.192335
# Minibatch accuracy: 60.9%
# Validation accuracy: 57.7%
# Minibatch loss at step 1500: 5.404131
# Minibatch accuracy: 68.1%
# Validation accuracy: 60.9%
# Minibatch loss at step 2000: 4.542363
# Minibatch accuracy: 69.1%
# Validation accuracy: 65.4%
# Minibatch loss at step 2500: 3.880163
# Minibatch accuracy: 77.5%
# Validation accuracy: 66.3%
# Minibatch loss at step 3000: 4.589217
# Minibatch accuracy: 73.1%
# Validation accuracy: 67.7%
# Minibatch loss at step 3500: 4.426017
# Minibatch accuracy: 72.8%
# Validation accuracy: 70.9%
# Minibatch loss at step 4000: 3.640088
# Minibatch accuracy: 79.1%
# Validation accuracy: 71.1%
# Minibatch loss at step 4500: 3.435755
# Minibatch accuracy: 80.9%
# Validation accuracy: 70.6%
# Minibatch loss at step 5000: 3.445349
# Minibatch accuracy: 81.9%
# Validation accuracy: 70.8%
# Minibatch loss at step 5500: 3.614540
# Minibatch accuracy: 79.7%
# Validation accuracy: 72.7%
# Minibatch loss at step 6000: 3.363847
# Minibatch accuracy: 82.8%
# Validation accuracy: 71.8%
# Minibatch loss at step 6500: 3.516423
# Minibatch accuracy: 80.9%
# Validation accuracy: 73.0%
# Minibatch loss at step 7000: 4.014165
# Minibatch accuracy: 78.4%
# Validation accuracy: 74.4%
# Minibatch loss at step 7500: 2.619600
# Minibatch accuracy: 86.9%
# Validation accuracy: 75.0%
# Minibatch loss at step 8000: 2.730596
# Minibatch accuracy: 85.6%
# Validation accuracy: 74.3%
# Minibatch loss at step 8500: 2.737415
# Minibatch accuracy: 85.0%
# Validation accuracy: 73.6%
# Minibatch loss at step 9000: 2.652473
# Minibatch accuracy: 84.7%
# Validation accuracy: 74.3%
# Minibatch loss at step 9500: 3.276055
# Minibatch accuracy: 82.5%
# Validation accuracy: 74.6%
# Minibatch loss at step 10000: 3.125678
# Minibatch accuracy: 81.6%
# Validation accuracy: 73.2%
# Minibatch loss at step 10500: 4.092864
# Minibatch accuracy: 75.3%
# Validation accuracy: 75.8%
# Minibatch loss at step 11000: 3.162516
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.5%
# Minibatch loss at step 11500: 2.041131
# Minibatch accuracy: 88.8%
# Validation accuracy: 75.7%
# Minibatch loss at step 12000: 2.587141
# Minibatch accuracy: 86.6%
# Validation accuracy: 76.5%
# Minibatch loss at step 12500: 1.962655
# Minibatch accuracy: 90.3%
# Validation accuracy: 76.2%
# Minibatch loss at step 13000: 2.686790
# Minibatch accuracy: 85.9%
# Validation accuracy: 76.7%
# Minibatch loss at step 13500: 2.565306
# Minibatch accuracy: 84.7%
# Validation accuracy: 76.2%
# Minibatch loss at step 14000: 4.262596
# Minibatch accuracy: 74.1%
# Validation accuracy: 77.3%
# Minibatch loss at step 14500: 2.562128
# Minibatch accuracy: 83.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 15000: 2.970003
# Minibatch accuracy: 82.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 15500: 2.944889
# Minibatch accuracy: 81.6%
# Validation accuracy: 77.1%
# Minibatch loss at step 16000: 2.231952
# Minibatch accuracy: 89.4%
# Validation accuracy: 76.4%
# Minibatch loss at step 16500: 2.405528
# Minibatch accuracy: 88.8%
# Validation accuracy: 76.4%
# Minibatch loss at step 17000: 1.822934
# Minibatch accuracy: 90.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 17500: 2.643382
# Minibatch accuracy: 83.1%
# Validation accuracy: 76.6%
# Minibatch loss at step 18000: 2.235815
# Minibatch accuracy: 88.4%
# Validation accuracy: 78.6%
# Minibatch loss at step 18500: 2.419503
# Minibatch accuracy: 87.2%
# Validation accuracy: 77.6%
# Minibatch loss at step 19000: 2.913724
# Minibatch accuracy: 84.1%
# Validation accuracy: 77.1%
# Minibatch loss at step 19500: 2.560354
# Minibatch accuracy: 86.2%
# Validation accuracy: 77.6%
# Minibatch loss at step 20000: 3.466758
# Minibatch accuracy: 83.1%
# Validation accuracy: 77.0%
# Minibatch loss at step 20500: 2.433628
# Minibatch accuracy: 88.1%
# Validation accuracy: 77.3%
# Minibatch loss at step 21000: 2.790032
# Minibatch accuracy: 85.9%
# Validation accuracy: 77.7%
# Minibatch loss at step 21500: 3.511439
# Minibatch accuracy: 79.1%
# Validation accuracy: 78.2%
# Minibatch loss at step 22000: 2.199755
# Minibatch accuracy: 87.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 22500: 1.968431
# Minibatch accuracy: 90.6%
# Validation accuracy: 78.2%
# Minibatch loss at step 23000: 2.565037
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.9%
# Minibatch loss at step 23500: 2.773976
# Minibatch accuracy: 84.1%
# Validation accuracy: 77.6%
# Minibatch loss at step 24000: 2.104282
# Minibatch accuracy: 88.4%
# Validation accuracy: 78.3%
# Minibatch loss at step 24500: 2.407461
# Minibatch accuracy: 86.6%
# Validation accuracy: 78.2%
# Minibatch loss at step 25000: 3.227014
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.1%
# Minibatch loss at step 25500: 2.622920
# Minibatch accuracy: 86.9%
# Validation accuracy: 78.2%
# Minibatch loss at step 26000: 2.000502
# Minibatch accuracy: 86.6%
# Validation accuracy: 78.6%
# Minibatch loss at step 26500: 1.797961
# Minibatch accuracy: 90.6%
# Validation accuracy: 78.2%
# Minibatch loss at step 27000: 2.571057
# Minibatch accuracy: 87.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 27500: 1.963545
# Minibatch accuracy: 89.4%
# Validation accuracy: 78.0%
# Minibatch loss at step 28000: 2.219502
# Minibatch accuracy: 89.1%
# Validation accuracy: 78.1%
# Minibatch loss at step 28500: 3.705783
# Minibatch accuracy: 77.2%
# Validation accuracy: 79.1%
# Minibatch loss at step 29000: 2.454963
# Minibatch accuracy: 86.2%
# Validation accuracy: 78.2%
# Minibatch loss at step 29500: 2.609215
# Minibatch accuracy: 85.3%
# Validation accuracy: 78.5%
# Minibatch loss at step 30000: 1.875089
# Minibatch accuracy: 90.0%
# Validation accuracy: 79.0%
# Minibatch loss at step 30500: 2.642878
# Minibatch accuracy: 85.9%
# Validation accuracy: 78.9%
# Minibatch loss at step 31000: 2.233103
# Minibatch accuracy: 87.8%
# Validation accuracy: 78.5%
# Minibatch loss at step 31500: 2.790633
# Minibatch accuracy: 87.2%
# Validation accuracy: 78.7%
# Minibatch loss at step 32000: 4.089015
# Minibatch accuracy: 76.9%
# Validation accuracy: 79.4%
# Minibatch loss at step 32500: 2.523843
# Minibatch accuracy: 84.1%
# Validation accuracy: 79.1%
# Minibatch loss at step 33000: 2.803806
# Minibatch accuracy: 83.4%
# Validation accuracy: 79.0%
# Minibatch loss at step 33500: 2.084118
# Minibatch accuracy: 89.1%
# Validation accuracy: 79.2%
# Minibatch loss at step 34000: 2.543740
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.6%
# Minibatch loss at step 34500: 2.850747
# Minibatch accuracy: 84.4%
# Validation accuracy: 79.0%
# Minibatch loss at step 35000: 2.820109
# Minibatch accuracy: 85.6%
# Validation accuracy: 78.7%
# Minibatch loss at step 35500: 3.993188
# Minibatch accuracy: 76.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 36000: 2.141310
# Minibatch accuracy: 89.7%
# Validation accuracy: 79.3%
# Minibatch loss at step 36500: 2.261540
# Minibatch accuracy: 87.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 37000: 1.975252
# Minibatch accuracy: 90.3%
# Validation accuracy: 79.4%
# Minibatch loss at step 37500: 2.562907
# Minibatch accuracy: 85.6%
# Validation accuracy: 79.5%
# Minibatch loss at step 38000: 2.938419
# Minibatch accuracy: 83.4%
# Validation accuracy: 78.9%
# Minibatch loss at step 38500: 2.045916
# Minibatch accuracy: 87.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 39000: 2.167913
# Minibatch accuracy: 89.7%
# Validation accuracy: 79.0%
# Minibatch loss at step 39500: 2.662581
# Minibatch accuracy: 85.6%
# Validation accuracy: 79.5%
# Minibatch loss at step 40000: 2.175032
# Minibatch accuracy: 85.9%
# Validation accuracy: 79.4%
# Minibatch loss at step 40500: 2.182158
# Minibatch accuracy: 87.8%
# Validation accuracy: 79.2%
# Minibatch loss at step 41000: 1.697921
# Minibatch accuracy: 91.9%
# Validation accuracy: 79.7%
# Minibatch loss at step 41500: 2.128101
# Minibatch accuracy: 87.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 42000: 2.475546
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 42500: 1.741417
# Minibatch accuracy: 91.6%
# Validation accuracy: 79.7%
# Minibatch loss at step 43000: 3.025569
# Minibatch accuracy: 82.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 43500: 1.725518
# Minibatch accuracy: 90.6%
# Validation accuracy: 79.4%
# Minibatch loss at step 44000: 2.523844
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 44500: 2.342411
# Minibatch accuracy: 88.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 45000: 2.152445
# Minibatch accuracy: 87.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 45500: 2.194869
# Minibatch accuracy: 89.1%
# Validation accuracy: 79.5%
# Minibatch loss at step 46000: 2.334039
# Minibatch accuracy: 89.4%
# Validation accuracy: 79.8%
# Minibatch loss at step 46500: 3.457302
# Minibatch accuracy: 78.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 47000: 2.284453
# Minibatch accuracy: 89.7%
# Validation accuracy: 80.0%
# Minibatch loss at step 47500: 1.709776
# Minibatch accuracy: 91.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 48000: 2.603783
# Minibatch accuracy: 85.9%
# Validation accuracy: 79.6%
# Minibatch loss at step 48500: 1.724190
# Minibatch accuracy: 91.6%
# Validation accuracy: 79.8%
# Minibatch loss at step 49000: 1.283107
# Minibatch accuracy: 92.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 49500: 2.081464
# Minibatch accuracy: 88.1%
# Validation accuracy: 79.5%
# Minibatch loss at step 50000: 3.488584
# Minibatch accuracy: 78.4%
# Validation accuracy: 79.8%
# Minibatch loss at step 50500: 1.706694
# Minibatch accuracy: 91.6%
# Validation accuracy: 80.0%
# Minibatch loss at step 51000: 1.927402
# Minibatch accuracy: 89.7%
# Validation accuracy: 80.1%
# Minibatch loss at step 51500: 1.666174
# Minibatch accuracy: 90.6%
# Validation accuracy: 80.0%
# Minibatch loss at step 52000: 2.560619
# Minibatch accuracy: 86.9%
# Validation accuracy: 79.8%
# Minibatch loss at step 52500: 2.561862
# Minibatch accuracy: 87.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 53000: 2.458939
# Minibatch accuracy: 85.9%
# Validation accuracy: 79.8%
# Minibatch loss at step 53500: 3.514437
# Minibatch accuracy: 80.9%
# Validation accuracy: 80.3%
# Minibatch loss at step 54000: 2.593788
# Minibatch accuracy: 85.3%
# Validation accuracy: 80.1%
# Minibatch loss at step 54500: 2.073583
# Minibatch accuracy: 89.4%
# Validation accuracy: 80.3%
# Minibatch loss at step 55000: 2.033779
# Minibatch accuracy: 88.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 55500: 1.867969
# Minibatch accuracy: 90.9%
# Validation accuracy: 79.8%
# Minibatch loss at step 56000: 2.139904
# Minibatch accuracy: 86.9%
# Validation accuracy: 80.0%
# Minibatch loss at step 56500: 2.518936
# Minibatch accuracy: 88.1%
# Validation accuracy: 80.2%
# Minibatch loss at step 57000: 2.138103
# Minibatch accuracy: 88.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 57500: 3.385489
# Minibatch accuracy: 77.8%
# Validation accuracy: 80.8%
# Minibatch loss at step 58000: 2.175654
# Minibatch accuracy: 89.7%
# Validation accuracy: 80.3%
# Minibatch loss at step 58500: 1.909631
# Minibatch accuracy: 89.1%
# Validation accuracy: 79.9%
# Minibatch loss at step 59000: 2.877549
# Minibatch accuracy: 85.9%
# Validation accuracy: 79.6%
# Minibatch loss at step 59500: 2.134885
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 60000: 2.062478
# Minibatch accuracy: 90.6%
# Validation accuracy: 80.0%
# Minibatch loss at step 60500: 1.920526
# Minibatch accuracy: 89.1%
# Validation accuracy: 80.1%
# Minibatch loss at step 61000: 3.207102
# Minibatch accuracy: 81.6%
# Validation accuracy: 80.7%
# Minibatch loss at step 61500: 1.674436
# Minibatch accuracy: 90.9%
# Validation accuracy: 80.4%
# Minibatch loss at step 62000: 1.870535
# Minibatch accuracy: 89.7%
# Validation accuracy: 80.3%
# Minibatch loss at step 62500: 2.269384
# Minibatch accuracy: 87.2%
# Validation accuracy: 80.1%
# Minibatch loss at step 63000: 1.979555
# Minibatch accuracy: 88.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 63500: 2.163298
# Minibatch accuracy: 86.6%
# Validation accuracy: 80.3%
# Minibatch loss at step 64000: 1.819056
# Minibatch accuracy: 90.6%
# Validation accuracy: 80.1%
# Minibatch loss at step 64500: 2.705603
# Minibatch accuracy: 84.7%
# Validation accuracy: 80.7%
# Minibatch loss at step 65000: 2.265220
# Minibatch accuracy: 87.8%
# Validation accuracy: 80.5%
# Minibatch loss at step 65500: 1.979584
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.5%
# Minibatch loss at step 66000: 1.260445
# Minibatch accuracy: 94.4%
# Validation accuracy: 80.5%
# Minibatch loss at step 66500: 1.831939
# Minibatch accuracy: 89.1%
# Validation accuracy: 80.3%
# Minibatch loss at step 67000: 1.948676
# Minibatch accuracy: 89.7%
# Validation accuracy: 80.4%
# Minibatch loss at step 67500: 2.259568
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 68000: 3.817818
# Minibatch accuracy: 79.4%
# Validation accuracy: 80.6%
# Minibatch loss at step 68500: 1.504834
# Minibatch accuracy: 92.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 69000: 1.942770
# Minibatch accuracy: 89.4%
# Validation accuracy: 80.7%
# Minibatch loss at step 69500: 2.456305
# Minibatch accuracy: 86.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 70000: 1.774365
# Minibatch accuracy: 90.6%
# Validation accuracy: 80.5%
# Minibatch loss at step 70500: 1.920636
# Minibatch accuracy: 88.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 71000: 2.409697
# Minibatch accuracy: 86.9%
# Validation accuracy: 80.6%
# Minibatch loss at step 71500: 3.180749
# Minibatch accuracy: 83.1%
# Validation accuracy: 80.7%
# Minibatch loss at step 72000: 1.886158
# Minibatch accuracy: 89.4%
# Validation accuracy: 80.8%
# Minibatch loss at step 72500: 2.579288
# Minibatch accuracy: 88.8%
# Validation accuracy: 80.6%
# Minibatch loss at step 73000: 1.453320
# Minibatch accuracy: 92.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 73500: 2.111022
# Minibatch accuracy: 89.7%
# Validation accuracy: 80.3%
# Minibatch loss at step 74000: 1.759733
# Minibatch accuracy: 92.5%
# Validation accuracy: 80.6%
# Minibatch loss at step 74500: 1.907941
# Minibatch accuracy: 88.8%
# Validation accuracy: 80.5%
# Minibatch loss at step 75000: 2.140833
# Minibatch accuracy: 88.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 75500: 1.456640
# Minibatch accuracy: 91.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 76000: 1.746542
# Minibatch accuracy: 90.9%
# Validation accuracy: 80.5%
# Minibatch loss at step 76500: 2.340213
# Minibatch accuracy: 86.9%
# Validation accuracy: 80.5%
# Minibatch loss at step 77000: 2.105238
# Minibatch accuracy: 90.3%
# Validation accuracy: 80.8%
# Minibatch loss at step 77500: 1.307943
# Minibatch accuracy: 95.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 78000: 2.368461
# Minibatch accuracy: 89.4%
# Validation accuracy: 80.8%
# Minibatch loss at step 78500: 2.802202
# Minibatch accuracy: 85.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 79000: 3.193553
# Minibatch accuracy: 79.4%
# Validation accuracy: 81.0%
# Minibatch loss at step 79500: 2.121441
# Minibatch accuracy: 90.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 80000: 2.204682
# Minibatch accuracy: 88.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 80500: 1.888309
# Minibatch accuracy: 89.4%
# Validation accuracy: 80.4%
# Minibatch loss at step 81000: 2.084078
# Minibatch accuracy: 88.8%
# Validation accuracy: 80.6%
# Minibatch loss at step 81500: 1.654798
# Minibatch accuracy: 91.6%
# Validation accuracy: 80.6%
# Minibatch loss at step 82000: 2.471508
# Minibatch accuracy: 86.9%
# Validation accuracy: 80.7%
# Minibatch loss at step 82500: 3.441666
# Minibatch accuracy: 79.4%
# Validation accuracy: 81.1%
# Minibatch loss at step 83000: 2.118916
# Minibatch accuracy: 90.6%
# Validation accuracy: 80.8%
# Minibatch loss at step 83500: 1.615765
# Minibatch accuracy: 91.9%
# Validation accuracy: 81.0%
# Minibatch loss at step 84000: 1.577837
# Minibatch accuracy: 90.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 84500: 2.000054
# Minibatch accuracy: 89.1%
# Validation accuracy: 80.8%
# Minibatch loss at step 85000: 1.619222
# Minibatch accuracy: 90.9%
# Validation accuracy: 80.8%
# Minibatch loss at step 85500: 1.703135
# Minibatch accuracy: 90.6%
# Validation accuracy: 80.5%
# Minibatch loss at step 86000: 3.216658
# Minibatch accuracy: 82.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 86500: 1.974999
# Minibatch accuracy: 90.6%
# Validation accuracy: 81.0%
# Minibatch loss at step 87000: 1.970126
# Minibatch accuracy: 90.9%
# Validation accuracy: 81.1%
# Minibatch loss at step 87500: 1.504604
# Minibatch accuracy: 92.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 88000: 2.096140
# Minibatch accuracy: 87.8%
# Validation accuracy: 80.6%
# Minibatch loss at step 88500: 2.085748
# Minibatch accuracy: 90.0%
# Validation accuracy: 80.9%
# Minibatch loss at step 89000: 2.037958
# Minibatch accuracy: 88.4%
# Validation accuracy: 80.8%
# Minibatch loss at step 89500: 2.890859
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 90000: 1.721865
# Minibatch accuracy: 90.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 90500: 2.179111
# Minibatch accuracy: 90.3%
# Validation accuracy: 81.1%
# Minibatch loss at step 91000: 1.923478
# Minibatch accuracy: 89.7%
# Validation accuracy: 80.8%
# Minibatch loss at step 91500: 2.185734
# Minibatch accuracy: 91.6%
# Validation accuracy: 80.6%
# Minibatch loss at step 92000: 1.870432
# Minibatch accuracy: 91.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 92500: 1.965630
# Minibatch accuracy: 90.6%
# Validation accuracy: 80.8%
# Minibatch loss at step 93000: 3.112295
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 93500: 1.872352
# Minibatch accuracy: 89.7%
# Validation accuracy: 81.4%
# Minibatch loss at step 94000: 2.053590
# Minibatch accuracy: 89.4%
# Validation accuracy: 80.9%
# Minibatch loss at step 94500: 1.390799
# Minibatch accuracy: 91.9%
# Validation accuracy: 81.0%
# Minibatch loss at step 95000: 1.631366
# Minibatch accuracy: 90.9%
# Validation accuracy: 80.9%
# Minibatch loss at step 95500: 1.696656
# Minibatch accuracy: 92.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 96000: 1.213835
# Minibatch accuracy: 92.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 96500: 1.587791
# Minibatch accuracy: 90.9%
# Validation accuracy: 81.1%
# Minibatch loss at step 97000: 2.538596
# Minibatch accuracy: 85.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 97500: 2.482900
# Minibatch accuracy: 86.6%
# Validation accuracy: 80.9%
# Minibatch loss at step 98000: 1.746270
# Minibatch accuracy: 90.3%
# Validation accuracy: 80.9%
# Minibatch loss at step 98500: 1.559966
# Minibatch accuracy: 91.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 99000: 1.383369
# Minibatch accuracy: 91.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 99500: 2.278474
# Minibatch accuracy: 89.1%
# Validation accuracy: 81.2%
# Minibatch loss at step 100000: 2.025070
# Minibatch accuracy: 90.9%
# Validation accuracy: 80.8%
# Test accuracy: 74.4%
# Model saved in file: CNN_multi.ckpt

# %%
image_size = 32
num_labels = 11 # 0-9, + blank 
num_channels = 1 # grayscale

batch_size = 64
patch_size = 5
depth1 = 16
depth2 = 32
depth3 = 64
num_hidden1 = 64
#num_hidden2 = 16
shape = [batch_size, image_size, image_size, num_channels]

# Construct a 7-layer CNN.
# C1: convolutional layer, batch_size x 28 x 28 x 16, convolution size: 5 x 5 x 1 x 16
# S2: sub-sampling layer, batch_size x 14 x 14 x 16
# C3: convolutional layer, batch_size x 10 x 10 x 32, convolution size: 5 x 5 x 16 x 32
# S4: sub-sampling layer, batch_size x 5 x 5 x 32
# C5: convolutional layer, batch_size x 1 x 1 x 64, convolution size: 5 x 5 x 32 x 64
# Dropout
# F6: fully-connected layer, weight size: 64 x 16
# Output layer, weight size: 16 x 10

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.int32, shape=(batch_size, 6))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.get_variable("W1", shape=[patch_size, patch_size, num_channels, depth1],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
  layer1_biases = tf.Variable(tf.constant(1.0, shape=[depth1]), name='B1')
  layer2_weights = tf.get_variable("W2", shape=[patch_size, patch_size, depth1, depth2],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]), name='B2')
  layer3_weights = tf.get_variable("W3", shape=[patch_size, patch_size, depth2, num_hidden1],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden1]), name='B3')

  s1_w = tf.get_variable("WS1", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s1_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS1')
  s2_w = tf.get_variable("WS2", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s2_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS2')
  s3_w = tf.get_variable("WS3", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s3_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS3')
  s4_w = tf.get_variable("WS4", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s4_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS4')
  s5_w = tf.get_variable("WS5", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s5_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS5')
  
  # Model.
  def model(data, keep_prob, shape):
    LCN = LecunLCN(data, shape)
    conv = tf.nn.conv2d(LCN, layer1_weights, [1,1,1,1], 'VALID', name='C1')
    hidden = tf.nn.relu(conv + layer1_biases)
    lrn = tf.nn.local_response_normalization(hidden)
    sub = tf.nn.max_pool(lrn, [1,2,2,1], [1,2,2,1], 'SAME', name='S2')
    conv = tf.nn.conv2d(sub, layer2_weights, [1,1,1,1], padding='VALID', name='C3')
    hidden = tf.nn.relu(conv + layer2_biases)
    lrn = tf.nn.local_response_normalization(hidden)
    sub = tf.nn.max_pool(lrn, [1,2,2,1], [1,2,2,1], 'SAME', name='S4')
    conv = tf.nn.conv2d(sub, layer3_weights, [1,1,1,1], padding='VALID', name='C5')
    hidden = tf.nn.relu(conv + layer3_biases)
    hidden = tf.nn.dropout(hidden, keep_prob)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    #hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    logits1 = tf.matmul(reshape, s1_w) + s1_b
    logits2 = tf.matmul(reshape, s2_w) + s2_b
    logits3 = tf.matmul(reshape, s3_w) + s3_b
    logits4 = tf.matmul(reshape, s4_w) + s4_b
    logits5 = tf.matmul(reshape, s5_w) + s5_b
    return [logits1, logits2, logits3, logits4, logits5]
  
  # Training computation.
  [logits1, logits2, logits3, logits4, logits5] = model(tf_train_dataset, 0.875, shape)
  loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits1, tf_train_labels[:,1])) +\
tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits2, tf_train_labels[:,2])) +\
tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits3, tf_train_labels[:,3])) +\
tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits4, tf_train_labels[:,4])) +\
tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits5, tf_train_labels[:,5]))
    
  # Optimizer.
  #optimizer = tf.train.AdagradOptimizer(0.01).minimize(loss)
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(0.05, global_step, 10000, 0.95)
  optimizer = tf.train.AdagradOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.pack([tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[0]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[1]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[2]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[3]),\
                      tf.nn.softmax(model(tf_train_dataset, 1.0, shape)[4])])
  valid_prediction = tf.pack([tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[0]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[1]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[2]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[3]),\
                      tf.nn.softmax(model(tf_valid_dataset, 1.0, shape)[4])])
  test_prediction = tf.pack([tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[0]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[1]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[2]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[3]),\
                     tf.nn.softmax(model(tf_test_dataset, 1.0, shape)[4])])
    
  saver = tf.train.Saver()

num_steps = 100001

with tf.Session(graph=graph) as session:
  saver.restore(session, "CNN_multi2.ckpt")
  print("Model restored.")  

  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size),:]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    
    if (step % 200 == 0): 
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels[:,1:6]))
      print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels[:,1:6]))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels[:,1:6]))
  save_path = saver.save(session, "CNN_multi2.ckpt")
  print("Model saved in file: %s" % save_path)
# Out:
# Model restored.
# Initialized
# Minibatch loss at step 0: 3.336032
# Minibatch accuracy: 81.9%
# Validation accuracy: 79.6%
# Minibatch loss at step 200: 3.179541
# Minibatch accuracy: 82.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 400: 2.475194
# Minibatch accuracy: 87.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 600: 1.897970
# Minibatch accuracy: 91.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 800: 2.522296
# Minibatch accuracy: 90.3%
# Validation accuracy: 86.6%
# Minibatch loss at step 1000: 2.167231
# Minibatch accuracy: 90.3%
# Validation accuracy: 87.1%
# Minibatch loss at step 1200: 1.904711
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 1400: 1.881925
# Minibatch accuracy: 91.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 1600: 1.953983
# Minibatch accuracy: 90.3%
# Validation accuracy: 88.0%
# Minibatch loss at step 1800: 1.578451
# Minibatch accuracy: 91.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 2000: 2.080619
# Minibatch accuracy: 91.9%
# Validation accuracy: 88.6%
# Minibatch loss at step 2200: 1.996728
# Minibatch accuracy: 90.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 2400: 1.228945
# Minibatch accuracy: 94.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 2600: 1.884061
# Minibatch accuracy: 92.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 2800: 1.499883
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 3000: 1.841959
# Minibatch accuracy: 89.4%
# Validation accuracy: 89.2%
# Minibatch loss at step 3200: 1.918526
# Minibatch accuracy: 88.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 3400: 2.250057
# Minibatch accuracy: 90.3%
# Validation accuracy: 89.4%
# Minibatch loss at step 3600: 1.546657
# Minibatch accuracy: 92.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 3800: 1.913087
# Minibatch accuracy: 90.9%
# Validation accuracy: 89.9%
# Minibatch loss at step 4000: 1.358716
# Minibatch accuracy: 93.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 4200: 1.300663
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.2%
# Minibatch loss at step 4400: 1.792294
# Minibatch accuracy: 91.6%
# Validation accuracy: 90.0%
# Minibatch loss at step 4600: 1.204995
# Minibatch accuracy: 94.4%
# Validation accuracy: 90.1%
# Minibatch loss at step 4800: 1.587956
# Minibatch accuracy: 92.8%
# Validation accuracy: 90.2%
# Minibatch loss at step 5000: 1.411271
# Minibatch accuracy: 93.4%
# Validation accuracy: 90.3%
# Minibatch loss at step 5200: 1.643587
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 5400: 2.108495
# Minibatch accuracy: 90.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 5600: 1.346823
# Minibatch accuracy: 93.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 5800: 1.704198
# Minibatch accuracy: 91.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 6000: 1.585029
# Minibatch accuracy: 90.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 6200: 1.520701
# Minibatch accuracy: 92.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 6400: 1.516659
# Minibatch accuracy: 91.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 6600: 1.593688
# Minibatch accuracy: 92.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 6800: 1.920403
# Minibatch accuracy: 89.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 7000: 1.586819
# Minibatch accuracy: 91.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 7200: 1.570563
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 7400: 1.916881
# Minibatch accuracy: 91.6%
# Validation accuracy: 90.8%
# Minibatch loss at step 7600: 1.908139
# Minibatch accuracy: 93.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 7800: 1.598195
# Minibatch accuracy: 91.9%
# Validation accuracy: 91.0%
# Minibatch loss at step 8000: 1.318044
# Minibatch accuracy: 94.1%
# Validation accuracy: 90.8%
# Minibatch loss at step 8200: 1.794152
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.0%
# Minibatch loss at step 8400: 1.464192
# Minibatch accuracy: 92.8%
# Validation accuracy: 91.1%
# Minibatch loss at step 8600: 1.227450
# Minibatch accuracy: 95.6%
# Validation accuracy: 91.0%
# Minibatch loss at step 8800: 1.982971
# Minibatch accuracy: 89.7%
# Validation accuracy: 91.1%
# Minibatch loss at step 9000: 1.818228
# Minibatch accuracy: 91.2%
# Validation accuracy: 91.1%
# Minibatch loss at step 9200: 1.596871
# Minibatch accuracy: 92.5%
# Validation accuracy: 91.1%
# Minibatch loss at step 9400: 1.340308
# Minibatch accuracy: 95.0%
# Validation accuracy: 91.2%
# Minibatch loss at step 9600: 1.414544
# Minibatch accuracy: 93.1%
# Validation accuracy: 91.1%
# Minibatch loss at step 9800: 1.303759
# Minibatch accuracy: 93.1%
# Validation accuracy: 91.2%
# Minibatch loss at step 10000: 1.248426
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.0%
# Minibatch loss at step 10200: 1.312371
# Minibatch accuracy: 94.1%
# Validation accuracy: 91.1%
# Minibatch loss at step 10400: 1.561381
# Minibatch accuracy: 94.1%
# Validation accuracy: 91.1%
# Minibatch loss at step 10600: 1.158792
# Minibatch accuracy: 92.5%
# Validation accuracy: 91.2%
# Minibatch loss at step 10800: 0.677446
# Minibatch accuracy: 96.6%
# Validation accuracy: 91.3%
# Minibatch loss at step 11000: 1.787030
# Minibatch accuracy: 91.6%
# Validation accuracy: 91.3%
# Minibatch loss at step 11200: 1.553312
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 11400: 1.487664
# Minibatch accuracy: 94.4%
# Validation accuracy: 91.4%
# Minibatch loss at step 11600: 1.376034
# Minibatch accuracy: 94.7%
# Validation accuracy: 91.4%
# Minibatch loss at step 11800: 1.238362
# Minibatch accuracy: 94.1%
# Validation accuracy: 91.4%
# Minibatch loss at step 12000: 1.575544
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 12200: 1.483045
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 12400: 1.658762
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.4%
# Minibatch loss at step 12600: 1.295549
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.4%
# Minibatch loss at step 12800: 1.652687
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 13000: 1.296121
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.5%
# Minibatch loss at step 13200: 1.930718
# Minibatch accuracy: 91.9%
# Validation accuracy: 91.5%
# Minibatch loss at step 13400: 1.673195
# Minibatch accuracy: 92.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 13600: 1.714084
# Minibatch accuracy: 94.7%
# Validation accuracy: 91.4%
# Minibatch loss at step 13800: 1.472664
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 14000: 2.362706
# Minibatch accuracy: 88.8%
# Validation accuracy: 91.4%
# Minibatch loss at step 14200: 1.707839
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.4%
# Minibatch loss at step 14400: 1.981166
# Minibatch accuracy: 90.9%
# Validation accuracy: 91.6%
# Minibatch loss at step 14600: 1.211218
# Minibatch accuracy: 94.1%
# Validation accuracy: 91.5%
# Minibatch loss at step 14800: 0.820176
# Minibatch accuracy: 96.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 15000: 1.471419
# Minibatch accuracy: 93.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 15200: 1.287248
# Minibatch accuracy: 94.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 15400: 1.729784
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 15600: 1.322039
# Minibatch accuracy: 92.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 15800: 1.564306
# Minibatch accuracy: 93.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 16000: 0.897971
# Minibatch accuracy: 96.2%
# Validation accuracy: 91.6%
# Minibatch loss at step 16200: 1.176716
# Minibatch accuracy: 94.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 16400: 1.390869
# Minibatch accuracy: 92.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 16600: 1.013991
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 16800: 1.439867
# Minibatch accuracy: 92.5%
# Validation accuracy: 91.4%
# Minibatch loss at step 17000: 1.022422
# Minibatch accuracy: 97.2%
# Validation accuracy: 91.8%
# Minibatch loss at step 17200: 1.301720
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 17400: 1.434950
# Minibatch accuracy: 92.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 17600: 1.165064
# Minibatch accuracy: 94.7%
# Validation accuracy: 91.6%
# Minibatch loss at step 17800: 2.254949
# Minibatch accuracy: 87.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 18000: 1.496555
# Minibatch accuracy: 95.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 18200: 1.228031
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 18400: 1.162248
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 18600: 1.964058
# Minibatch accuracy: 90.3%
# Validation accuracy: 91.9%
# Minibatch loss at step 18800: 1.581617
# Minibatch accuracy: 93.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 19000: 1.323846
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 19200: 1.658266
# Minibatch accuracy: 92.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 19400: 1.039011
# Minibatch accuracy: 94.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 19600: 1.066787
# Minibatch accuracy: 94.7%
# Validation accuracy: 91.7%
# Minibatch loss at step 19800: 1.305957
# Minibatch accuracy: 91.2%
# Validation accuracy: 91.9%
# Minibatch loss at step 20000: 0.818095
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.0%
# Minibatch loss at step 20200: 0.927678
# Minibatch accuracy: 96.6%
# Validation accuracy: 91.9%
# Minibatch loss at step 20400: 1.497891
# Minibatch accuracy: 92.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 20600: 1.152047
# Minibatch accuracy: 94.7%
# Validation accuracy: 91.9%
# Minibatch loss at step 20800: 1.135646
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 21000: 1.195543
# Minibatch accuracy: 93.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 21200: 1.585382
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 21400: 1.811307
# Minibatch accuracy: 90.9%
# Validation accuracy: 91.6%
# Minibatch loss at step 21600: 1.014553
# Minibatch accuracy: 94.4%
# Validation accuracy: 91.9%
# Minibatch loss at step 21800: 1.567012
# Minibatch accuracy: 92.5%
# Validation accuracy: 92.0%
# Minibatch loss at step 22000: 1.361029
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 22200: 1.128559
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.0%
# Minibatch loss at step 22400: 1.294033
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.1%
# Minibatch loss at step 22600: 1.138356
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 22800: 1.204783
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 23000: 0.950707
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.0%
# Minibatch loss at step 23200: 1.309959
# Minibatch accuracy: 92.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 23400: 1.274736
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 23600: 1.162352
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.0%
# Minibatch loss at step 23800: 1.111759
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.0%
# Minibatch loss at step 24000: 1.224027
# Minibatch accuracy: 95.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 24200: 1.251095
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.9%
# Minibatch loss at step 24400: 1.189440
# Minibatch accuracy: 95.6%
# Validation accuracy: 91.9%
# Minibatch loss at step 24600: 1.133348
# Minibatch accuracy: 95.9%
# Validation accuracy: 91.9%
# Minibatch loss at step 24800: 1.188616
# Minibatch accuracy: 93.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 25000: 1.611270
# Minibatch accuracy: 91.6%
# Validation accuracy: 91.8%
# Minibatch loss at step 25200: 1.119874
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 25400: 0.817125
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.1%
# Minibatch loss at step 25600: 1.274659
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 25800: 1.526516
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 26000: 1.492031
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 26200: 1.294588
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.0%
# Minibatch loss at step 26400: 1.680682
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 26600: 0.909176
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.0%
# Minibatch loss at step 26800: 1.234239
# Minibatch accuracy: 93.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 27000: 1.215514
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.1%
# Minibatch loss at step 27200: 1.538404
# Minibatch accuracy: 91.6%
# Validation accuracy: 92.1%
# Minibatch loss at step 27400: 1.282478
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.0%
# Minibatch loss at step 27600: 1.430812
# Minibatch accuracy: 92.8%
# Validation accuracy: 92.1%
# Minibatch loss at step 27800: 0.999231
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 28000: 0.947269
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 28200: 1.542163
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 28400: 1.671592
# Minibatch accuracy: 91.6%
# Validation accuracy: 91.9%
# Minibatch loss at step 28600: 2.022716
# Minibatch accuracy: 90.3%
# Validation accuracy: 92.0%
# Minibatch loss at step 28800: 1.437107
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.1%
# Minibatch loss at step 29000: 1.504768
# Minibatch accuracy: 91.9%
# Validation accuracy: 92.1%
# Minibatch loss at step 29200: 1.257161
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 29400: 0.899006
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.3%
# Minibatch loss at step 29600: 0.934450
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 29800: 1.091498
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 30000: 1.225893
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 30200: 1.047614
# Minibatch accuracy: 97.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 30400: 1.301930
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 30600: 1.156411
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 30800: 1.227736
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 31000: 1.097269
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.2%
# Minibatch loss at step 31200: 1.055193
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.2%
# Minibatch loss at step 31400: 0.853469
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 31600: 0.864696
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.1%
# Minibatch loss at step 31800: 0.911629
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.2%
# Minibatch loss at step 32000: 1.360465
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 32200: 1.572176
# Minibatch accuracy: 90.9%
# Validation accuracy: 92.0%
# Minibatch loss at step 32400: 1.211888
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 32600: 1.140689
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.2%
# Minibatch loss at step 32800: 1.070839
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 33000: 1.510998
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 33200: 1.166469
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.4%
# Minibatch loss at step 33400: 1.316746
# Minibatch accuracy: 92.5%
# Validation accuracy: 92.3%
# Minibatch loss at step 33600: 1.092928
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 33800: 1.543673
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.4%
# Minibatch loss at step 34000: 1.797279
# Minibatch accuracy: 91.6%
# Validation accuracy: 92.4%
# Minibatch loss at step 34200: 1.274122
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 34400: 1.280001
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 34600: 1.111560
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.2%
# Minibatch loss at step 34800: 1.133108
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 35000: 0.833502
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.2%
# Minibatch loss at step 35200: 1.158022
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 35400: 1.202803
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.3%
# Minibatch loss at step 35600: 2.064590
# Minibatch accuracy: 88.8%
# Validation accuracy: 92.1%
# Minibatch loss at step 35800: 1.454177
# Minibatch accuracy: 92.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 36000: 1.495237
# Minibatch accuracy: 92.5%
# Validation accuracy: 92.4%
# Minibatch loss at step 36200: 1.175703
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.4%
# Minibatch loss at step 36400: 1.036048
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 36600: 1.285967
# Minibatch accuracy: 92.5%
# Validation accuracy: 92.4%
# Minibatch loss at step 36800: 1.259526
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 37000: 1.258562
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.4%
# Minibatch loss at step 37200: 1.318503
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 37400: 1.278092
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.4%
# Minibatch loss at step 37600: 0.983894
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.5%
# Minibatch loss at step 37800: 1.282819
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.4%
# Minibatch loss at step 38000: 0.902580
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 38200: 0.786702
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 38400: 1.110605
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 38600: 1.453375
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 38800: 0.910529
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 39000: 1.078251
# Minibatch accuracy: 93.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 39200: 1.841511
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 39400: 1.451328
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 39600: 1.027235
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 39800: 0.992256
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 40000: 1.433240
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 40200: 0.974844
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.5%
# Minibatch loss at step 40400: 1.212751
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 40600: 1.347365
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.4%
# Minibatch loss at step 40800: 1.366381
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.4%
# Minibatch loss at step 41000: 1.079657
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.4%
# Minibatch loss at step 41200: 1.334335
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.4%
# Minibatch loss at step 41400: 1.301663
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.4%
# Minibatch loss at step 41600: 1.352653
# Minibatch accuracy: 93.1%
# Validation accuracy: 92.3%
# Minibatch loss at step 41800: 1.035703
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 42000: 1.561874
# Minibatch accuracy: 92.8%
# Validation accuracy: 92.4%
# Minibatch loss at step 42200: 1.162596
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.4%
# Minibatch loss at step 42400: 1.370293
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.3%
# Minibatch loss at step 42600: 1.054208
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 42800: 1.380764
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 43000: 1.392726
# Minibatch accuracy: 93.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 43200: 0.743766
# Minibatch accuracy: 97.2%
# Validation accuracy: 92.5%
# Minibatch loss at step 43400: 1.002624
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.4%
# Minibatch loss at step 43600: 1.397074
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.4%
# Minibatch loss at step 43800: 1.191630
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.5%
# Minibatch loss at step 44000: 1.062465
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.5%
# Minibatch loss at step 44200: 1.182233
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 44400: 1.131017
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.5%
# Minibatch loss at step 44600: 1.176593
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.5%
# Minibatch loss at step 44800: 1.941326
# Minibatch accuracy: 92.8%
# Validation accuracy: 92.4%
# Minibatch loss at step 45000: 1.011174
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.5%
# Minibatch loss at step 45200: 1.061767
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 45400: 0.846427
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.5%
# Minibatch loss at step 45600: 1.156893
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.5%
# Minibatch loss at step 45800: 1.144253
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 46000: 0.862086
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.4%
# Minibatch loss at step 46200: 1.057929
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.5%
# Minibatch loss at step 46400: 0.911662
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.3%
# Minibatch loss at step 46600: 1.472662
# Minibatch accuracy: 91.2%
# Validation accuracy: 92.5%
# Minibatch loss at step 46800: 1.172509
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.5%
# Minibatch loss at step 47000: 0.801939
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.5%
# Minibatch loss at step 47200: 1.107904
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.6%
# Minibatch loss at step 47400: 1.031258
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.6%
# Minibatch loss at step 47600: 1.158740
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.6%
# Minibatch loss at step 47800: 0.963791
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.6%
# Minibatch loss at step 48000: 1.262256
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.5%
# Minibatch loss at step 48200: 1.300420
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.6%
# Minibatch loss at step 48400: 0.761978
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.5%
# Minibatch loss at step 48600: 1.473328
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.6%
# Minibatch loss at step 48800: 1.140301
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.6%
# Minibatch loss at step 49000: 1.641953
# Minibatch accuracy: 92.8%
# Validation accuracy: 92.5%
# Minibatch loss at step 49200: 1.215116
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.5%
# Minibatch loss at step 49400: 0.946259
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.5%
# Minibatch loss at step 49600: 0.962579
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.4%
# Minibatch loss at step 49800: 1.268217
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.6%
# Minibatch loss at step 50000: 0.885045
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.4%
# Minibatch loss at step 50200: 1.685568
# Minibatch accuracy: 93.1%
# Validation accuracy: 92.5%
# Minibatch loss at step 50400: 1.149912
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.6%
# Minibatch loss at step 50600: 1.186513
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.6%
# Minibatch loss at step 50800: 1.063288
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.5%
# Minibatch loss at step 51000: 1.311149
# Minibatch accuracy: 93.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 51200: 1.017497
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.6%
# Minibatch loss at step 51400: 1.687893
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 51600: 1.002579
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.6%
# Minibatch loss at step 51800: 0.758074
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.6%
# Minibatch loss at step 52000: 1.020762
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.6%
# Minibatch loss at step 52200: 0.981529
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.7%
# Minibatch loss at step 52400: 1.158908
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.5%
# Minibatch loss at step 52600: 0.842835
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.6%
# Minibatch loss at step 52800: 1.571652
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.6%
# Minibatch loss at step 53000: 0.743061
# Minibatch accuracy: 97.2%
# Validation accuracy: 92.6%
# Minibatch loss at step 53200: 1.847629
# Minibatch accuracy: 90.0%
# Validation accuracy: 92.6%
# Minibatch loss at step 53400: 1.103573
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.5%
# Minibatch loss at step 53600: 1.572564
# Minibatch accuracy: 91.9%
# Validation accuracy: 92.6%
# Minibatch loss at step 53800: 1.047291
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.6%
# Minibatch loss at step 54000: 1.121381
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.7%
# Minibatch loss at step 54200: 1.187591
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.7%
# Minibatch loss at step 54400: 0.898356
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 54600: 0.941083
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 54800: 0.924768
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.7%
# Minibatch loss at step 55000: 0.839389
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 55200: 0.921658
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.6%
# Minibatch loss at step 55400: 0.997551
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 55600: 1.629577
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.6%
# Minibatch loss at step 55800: 1.505018
# Minibatch accuracy: 92.5%
# Validation accuracy: 92.7%
# Minibatch loss at step 56000: 1.050625
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.6%
# Minibatch loss at step 56200: 0.950008
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.6%
# Minibatch loss at step 56400: 0.945076
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.6%
# Minibatch loss at step 56600: 0.879972
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.6%
# Minibatch loss at step 56800: 0.779283
# Minibatch accuracy: 97.5%
# Validation accuracy: 92.6%
# Minibatch loss at step 57000: 1.244041
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.6%
# Minibatch loss at step 57200: 2.162884
# Minibatch accuracy: 91.6%
# Validation accuracy: 92.5%
# Minibatch loss at step 57400: 0.893449
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.6%
# Minibatch loss at step 57600: 1.201606
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.7%
# Minibatch loss at step 57800: 1.291927
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.7%
# Minibatch loss at step 58000: 1.864417
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.7%
# Minibatch loss at step 58200: 0.930227
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 58400: 0.989977
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 58600: 0.771085
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 58800: 1.186655
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.7%
# Minibatch loss at step 59000: 1.007826
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 59200: 1.312992
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.8%
# Minibatch loss at step 59400: 1.001827
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 59600: 1.194592
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.7%
# Minibatch loss at step 59800: 1.413709
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.6%
# Minibatch loss at step 60000: 0.858807
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.7%
# Minibatch loss at step 60200: 1.032451
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.7%
# Minibatch loss at step 60400: 1.248330
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.7%
# Minibatch loss at step 60600: 1.196535
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.7%
# Minibatch loss at step 60800: 1.359659
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.6%
# Minibatch loss at step 61000: 1.346149
# Minibatch accuracy: 91.9%
# Validation accuracy: 92.6%
# Minibatch loss at step 61200: 0.955231
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.7%
# Minibatch loss at step 61400: 1.062828
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 61600: 0.973432
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 61800: 1.449488
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.8%
# Minibatch loss at step 62000: 0.888233
# Minibatch accuracy: 97.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 62200: 0.671085
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 62400: 1.481996
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 62600: 0.963731
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 62800: 0.801136
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 63000: 1.397838
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.8%
# Minibatch loss at step 63200: 1.102895
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.9%
# Minibatch loss at step 63400: 0.752080
# Minibatch accuracy: 97.8%
# Validation accuracy: 92.8%
# Minibatch loss at step 63600: 0.896709
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 63800: 1.455398
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.7%
# Minibatch loss at step 64000: 1.020986
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 64200: 0.939049
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.6%
# Minibatch loss at step 64400: 1.862295
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.7%
# Minibatch loss at step 64600: 1.602300
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.7%
# Minibatch loss at step 64800: 1.041788
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.8%
# Minibatch loss at step 65000: 0.604748
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 65200: 0.879382
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 65400: 0.885564
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 65600: 0.825052
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.9%
# Minibatch loss at step 65800: 0.836300
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 66000: 0.921766
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 66200: 0.825305
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 66400: 1.109246
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 66600: 1.044111
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 66800: 1.081541
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.8%
# Minibatch loss at step 67000: 0.934359
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 67200: 0.954701
# Minibatch accuracy: 97.2%
# Validation accuracy: 92.7%
# Minibatch loss at step 67400: 1.460881
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 67600: 1.196845
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.8%
# Minibatch loss at step 67800: 1.415951
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.7%
# Minibatch loss at step 68000: 1.299156
# Minibatch accuracy: 93.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 68200: 1.459531
# Minibatch accuracy: 90.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 68400: 0.940131
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 68600: 0.878141
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 68800: 0.866046
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.9%
# Minibatch loss at step 69000: 0.936604
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 69200: 1.163533
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.9%
# Minibatch loss at step 69400: 1.256109
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 69600: 0.840816
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 69800: 0.790723
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 70000: 1.360933
# Minibatch accuracy: 92.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 70200: 0.931422
# Minibatch accuracy: 97.2%
# Validation accuracy: 92.9%
# Minibatch loss at step 70400: 1.099293
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 70600: 0.951880
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 70800: 0.606631
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.7%
# Minibatch loss at step 71000: 1.309780
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.8%
# Minibatch loss at step 71200: 1.026988
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.8%
# Minibatch loss at step 71400: 1.240214
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 71600: 1.256624
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 71800: 1.774934
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.7%
# Minibatch loss at step 72000: 1.130155
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 72200: 1.232562
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.9%
# Minibatch loss at step 72400: 1.193590
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 72600: 0.932070
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 72800: 1.083311
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.9%
# Minibatch loss at step 73000: 0.934503
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 73200: 0.769440
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 73400: 0.749181
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 73600: 0.814774
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 73800: 1.208378
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.9%
# Minibatch loss at step 74000: 0.756989
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.9%
# Minibatch loss at step 74200: 1.062218
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.9%
# Minibatch loss at step 74400: 0.803114
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 74600: 1.151322
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.8%
# Minibatch loss at step 74800: 1.309484
# Minibatch accuracy: 92.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 75000: 0.917436
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 75200: 1.096139
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.8%
# Minibatch loss at step 75400: 1.087743
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.7%
# Minibatch loss at step 75600: 1.351889
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.8%
# Minibatch loss at step 75800: 1.329205
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 76000: 0.812851
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 76200: 1.202273
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.8%
# Minibatch loss at step 76400: 0.897142
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 76600: 1.387358
# Minibatch accuracy: 93.4%
# Validation accuracy: 92.9%
# Minibatch loss at step 76800: 0.996455
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.9%
# Minibatch loss at step 77000: 1.474816
# Minibatch accuracy: 93.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 77200: 0.689569
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 77400: 0.930165
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 77600: 1.034807
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 77800: 0.820919
# Minibatch accuracy: 97.5%
# Validation accuracy: 92.9%
# Minibatch loss at step 78000: 0.801696
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.9%
# Minibatch loss at step 78200: 1.142659
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.8%
# Minibatch loss at step 78400: 1.275237
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 78600: 0.973164
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.7%
# Minibatch loss at step 78800: 1.870064
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.7%
# Minibatch loss at step 79000: 1.783041
# Minibatch accuracy: 91.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 79200: 0.977734
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 79400: 1.190795
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 79600: 1.328821
# Minibatch accuracy: 92.8%
# Validation accuracy: 93.0%
# Minibatch loss at step 79800: 1.009363
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.9%
# Minibatch loss at step 80000: 1.270234
# Minibatch accuracy: 93.1%
# Validation accuracy: 93.0%
# Minibatch loss at step 80200: 1.192002
# Minibatch accuracy: 96.2%
# Validation accuracy: 93.0%
# Minibatch loss at step 80400: 1.179498
# Minibatch accuracy: 93.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 80600: 1.241996
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.9%
# Minibatch loss at step 80800: 1.081826
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.9%
# Minibatch loss at step 81000: 1.436677
# Minibatch accuracy: 93.1%
# Validation accuracy: 93.0%
# Minibatch loss at step 81200: 0.816730
# Minibatch accuracy: 96.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 81400: 0.984651
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 81600: 1.086572
# Minibatch accuracy: 96.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 81800: 0.948503
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.8%
# Minibatch loss at step 82000: 1.477618
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.9%
# Minibatch loss at step 82200: 0.906085
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.9%
# Minibatch loss at step 82400: 1.062793
# Minibatch accuracy: 94.7%
# Validation accuracy: 92.9%
# Minibatch loss at step 82600: 1.067006
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 82800: 0.922218
# Minibatch accuracy: 97.2%
# Validation accuracy: 93.0%
# Minibatch loss at step 83000: 0.765419
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 83200: 0.802759
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.9%
# Minibatch loss at step 83400: 0.887930
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 83600: 0.772364
# Minibatch accuracy: 96.2%
# Validation accuracy: 93.1%
# Minibatch loss at step 83800: 1.211483
# Minibatch accuracy: 94.7%
# Validation accuracy: 93.0%
# Minibatch loss at step 84000: 0.838158
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.9%
# Minibatch loss at step 84200: 1.068025
# Minibatch accuracy: 95.0%
# Validation accuracy: 93.0%
# Minibatch loss at step 84400: 0.746776
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.9%
# Minibatch loss at step 84600: 0.658952
# Minibatch accuracy: 97.2%
# Validation accuracy: 93.0%
# Minibatch loss at step 84800: 1.014485
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 85000: 0.996861
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 85200: 0.769163
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 85400: 1.188140
# Minibatch accuracy: 94.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 85600: 0.766210
# Minibatch accuracy: 97.8%
# Validation accuracy: 93.0%
# Minibatch loss at step 85800: 1.022942
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.9%
# Minibatch loss at step 86000: 1.516326
# Minibatch accuracy: 93.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 86200: 1.078634
# Minibatch accuracy: 92.8%
# Validation accuracy: 93.0%
# Minibatch loss at step 86400: 0.827651
# Minibatch accuracy: 95.9%
# Validation accuracy: 93.0%
# Minibatch loss at step 86600: 0.788528
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 86800: 0.877426
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 87000: 0.974796
# Minibatch accuracy: 96.6%
# Validation accuracy: 92.9%
# Minibatch loss at step 87200: 1.268876
# Minibatch accuracy: 94.4%
# Validation accuracy: 93.0%
# Minibatch loss at step 87400: 0.878715
# Minibatch accuracy: 97.2%
# Validation accuracy: 93.0%
# Minibatch loss at step 87600: 1.416092
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.1%
# Minibatch loss at step 87800: 1.308629
# Minibatch accuracy: 94.4%
# Validation accuracy: 92.9%
# Minibatch loss at step 88000: 1.103439
# Minibatch accuracy: 93.4%
# Validation accuracy: 93.0%
# Minibatch loss at step 88200: 1.144271
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.0%
# Minibatch loss at step 88400: 1.087509
# Minibatch accuracy: 94.7%
# Validation accuracy: 93.0%
# Minibatch loss at step 88600: 0.918075
# Minibatch accuracy: 95.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 88800: 0.926036
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 89000: 1.268995
# Minibatch accuracy: 95.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 89200: 0.959815
# Minibatch accuracy: 95.9%
# Validation accuracy: 93.0%
# Minibatch loss at step 89400: 0.905243
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.0%
# Minibatch loss at step 89600: 1.042269
# Minibatch accuracy: 95.6%
# Validation accuracy: 92.9%
# Minibatch loss at step 89800: 1.020671
# Minibatch accuracy: 94.1%
# Validation accuracy: 93.0%
# Minibatch loss at step 90000: 1.044211
# Minibatch accuracy: 94.7%
# Validation accuracy: 93.0%
# Minibatch loss at step 90200: 0.660901
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 90400: 0.832731
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.0%
# Minibatch loss at step 90600: 0.917212
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 90800: 1.044165
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.1%
# Minibatch loss at step 91000: 0.885467
# Minibatch accuracy: 95.0%
# Validation accuracy: 93.0%
# Minibatch loss at step 91200: 0.758319
# Minibatch accuracy: 96.6%
# Validation accuracy: 93.1%
# Minibatch loss at step 91400: 0.649817
# Minibatch accuracy: 98.4%
# Validation accuracy: 93.0%
# Minibatch loss at step 91600: 1.122314
# Minibatch accuracy: 96.2%
# Validation accuracy: 93.0%
# Minibatch loss at step 91800: 1.315962
# Minibatch accuracy: 91.9%
# Validation accuracy: 93.0%
# Minibatch loss at step 92000: 0.717713
# Minibatch accuracy: 95.9%
# Validation accuracy: 93.0%
# Minibatch loss at step 92200: 1.052538
# Minibatch accuracy: 96.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 92400: 0.862365
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 92600: 0.935472
# Minibatch accuracy: 96.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 92800: 0.535578
# Minibatch accuracy: 98.1%
# Validation accuracy: 93.0%
# Minibatch loss at step 93000: 1.958050
# Minibatch accuracy: 90.3%
# Validation accuracy: 93.0%
# Minibatch loss at step 93200: 1.566622
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.9%
# Minibatch loss at step 93400: 1.153865
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 93600: 0.841295
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 93800: 0.942760
# Minibatch accuracy: 95.9%
# Validation accuracy: 93.0%
# Minibatch loss at step 94000: 0.910258
# Minibatch accuracy: 95.0%
# Validation accuracy: 93.1%
# Minibatch loss at step 94200: 0.990545
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 94400: 0.934941
# Minibatch accuracy: 94.1%
# Validation accuracy: 93.0%
# Minibatch loss at step 94600: 1.002526
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 94800: 0.900824
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 95000: 0.749526
# Minibatch accuracy: 97.5%
# Validation accuracy: 93.0%
# Minibatch loss at step 95200: 0.807522
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.0%
# Minibatch loss at step 95400: 0.884855
# Minibatch accuracy: 96.6%
# Validation accuracy: 93.1%
# Minibatch loss at step 95600: 0.869694
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.1%
# Minibatch loss at step 95800: 0.929947
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 96000: 0.927946
# Minibatch accuracy: 95.0%
# Validation accuracy: 93.0%
# Minibatch loss at step 96200: 0.667782
# Minibatch accuracy: 98.1%
# Validation accuracy: 93.0%
# Minibatch loss at step 96400: 0.848867
# Minibatch accuracy: 95.0%
# Validation accuracy: 93.0%
# Minibatch loss at step 96600: 1.197367
# Minibatch accuracy: 93.1%
# Validation accuracy: 93.0%
# Minibatch loss at step 96800: 1.501799
# Minibatch accuracy: 91.2%
# Validation accuracy: 93.0%
# Minibatch loss at step 97000: 1.382033
# Minibatch accuracy: 93.4%
# Validation accuracy: 93.0%
# Minibatch loss at step 97200: 0.842910
# Minibatch accuracy: 97.8%
# Validation accuracy: 93.0%
# Minibatch loss at step 97400: 0.935176
# Minibatch accuracy: 96.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 97600: 1.080192
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.1%
# Minibatch loss at step 97800: 1.074650
# Minibatch accuracy: 94.4%
# Validation accuracy: 93.0%
# Minibatch loss at step 98000: 0.910403
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.1%
# Minibatch loss at step 98200: 1.269342
# Minibatch accuracy: 92.8%
# Validation accuracy: 93.0%
# Minibatch loss at step 98400: 1.171215
# Minibatch accuracy: 97.2%
# Validation accuracy: 93.0%
# Minibatch loss at step 98600: 0.860875
# Minibatch accuracy: 97.2%
# Validation accuracy: 93.0%
# Minibatch loss at step 98800: 1.250444
# Minibatch accuracy: 95.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 99000: 0.645277
# Minibatch accuracy: 97.5%
# Validation accuracy: 93.1%
# Minibatch loss at step 99200: 1.239748
# Minibatch accuracy: 95.0%
# Validation accuracy: 93.1%
# Minibatch loss at step 99400: 0.921603
# Minibatch accuracy: 95.9%
# Validation accuracy: 93.1%
# Minibatch loss at step 99600: 1.310364
# Minibatch accuracy: 92.8%
# Validation accuracy: 93.0%
# Minibatch loss at step 99800: 0.776654
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.0%
# Minibatch loss at step 100000: 1.016988
# Minibatch accuracy: 97.8%
# Validation accuracy: 93.0%
# Test accuracy: 93.7%
# Model saved in file: CNN_multi2.ckpt

# %%
from PIL import Image
import os
import sys
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = (20.0, 20.0)
f, ax = plt.subplots(nrows=1, ncols=10)

im_samples = []
    
for i, j in enumerate(np.sort(np.random.randint(0, test_labels.shape[0], size=10))):
    filename = str(j+1)+'.png'
    fullname = os.path.join('test', filename)
    im = Image.open(fullname)
    house_num = ''
    for k in np.arange(test_labels[j,0]):
        house_num += str(test_labels[j,k+1])
    im_samples.extend([j])
    ax[i].axis('off')
    ax[i].set_title(house_num, loc='center')
    ax[i].imshow(im)

# %%
image_size = 32
num_labels = 11 # 0-9, + blank 
num_channels = 1 # grayscale

patch_size = 5
depth1 = 16
depth2 = 32
depth3 = 64
num_hidden1 = 64
shape = [batch_size, image_size, image_size, num_channels]

graph = tf.Graph()
with graph.as_default():

  # Input data.
  tf_test_dataset = tf.placeholder(tf.float32, shape=(10, 32, 32, 1))
  
  # Variables.
  layer1_weights = tf.get_variable("W1", shape=[patch_size, patch_size, num_channels, depth1],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
  layer1_biases = tf.Variable(tf.constant(1.0, shape=[depth1]), name='B1')
  layer2_weights = tf.get_variable("W2", shape=[patch_size, patch_size, depth1, depth2],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]), name='B2')
  layer3_weights = tf.get_variable("W3", shape=[patch_size, patch_size, depth2, num_hidden1],\
           initializer=tf.contrib.layers.xavier_initializer_conv2d())
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden1]), name='B3')

  s1_w = tf.get_variable("WS1", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s1_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS1')
  s2_w = tf.get_variable("WS2", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s2_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS2')
  s3_w = tf.get_variable("WS3", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s3_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS3')
  s4_w = tf.get_variable("WS4", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s4_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS4')
  s5_w = tf.get_variable("WS5", shape=[num_hidden1, num_labels],\
           initializer=tf.contrib.layers.xavier_initializer())
  s5_b = tf.Variable(tf.constant(1.0, shape=[num_labels]), name='BS5')
  
  # Model.
  def model(data, keep_prob, shape):
    LCN = LecunLCN(data, shape)
    conv = tf.nn.conv2d(LCN, layer1_weights, [1,1,1,1], 'VALID', name='C1')
    hidden = tf.nn.relu(conv + layer1_biases)
    lrn = tf.nn.local_response_normalization(hidden)
    sub = tf.nn.max_pool(lrn, [1,2,2,1], [1,2,2,1], 'SAME', name='S2')
    conv = tf.nn.conv2d(sub, layer2_weights, [1,1,1,1], padding='VALID', name='C3')
    hidden = tf.nn.relu(conv + layer2_biases)
    lrn = tf.nn.local_response_normalization(hidden)
    sub = tf.nn.max_pool(lrn, [1,2,2,1], [1,2,2,1], 'SAME', name='S4')
    conv = tf.nn.conv2d(sub, layer3_weights, [1,1,1,1], padding='VALID', name='C5')
    hidden = tf.nn.relu(conv + layer3_biases)
    hidden = tf.nn.dropout(hidden, keep_prob)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    #hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    logits1 = tf.matmul(reshape, s1_w) + s1_b
    logits2 = tf.matmul(reshape, s2_w) + s2_b
    logits3 = tf.matmul(reshape, s3_w) + s3_b
    logits4 = tf.matmul(reshape, s4_w) + s4_b
    logits5 = tf.matmul(reshape, s5_w) + s5_b
    return [logits1, logits2, logits3, logits4, logits5]
  
  # Training computation.
  [logits1, logits2, logits3, logits4, logits5] = model(tf_test_dataset, 0.5, shape)

  predict = tf.pack([tf.nn.softmax(logits1),tf.nn.softmax(logits2),tf.nn.softmax(logits3),\
                         tf.nn.softmax(logits4),tf.nn.softmax(logits5)])
  test_prediction = tf.transpose(tf.argmax(predict, 2))
  saver = tf.train.Saver()

with tf.Session(graph=graph) as session:
  saver.restore(session, "CNN_multi2.ckpt")
  print("Model restored.")  

  print('Initialized')
  test_prediction = session.run(test_prediction, feed_dict={tf_test_dataset : test_dataset[im_samples,:,:,:],})
  print(test_prediction)
# Out:
# Model restored.
# Initialized
# [[ 3  7 10 10 10]
#  [ 1  4  3 10 10]
#  [ 9 10 10 10 10]
#  [ 1  9  5 10 10]
#  [ 3  5  5 10 10]
#  [ 2 10 10 10 10]
#  [ 3  6  3 10 10]
#  [ 8 10 10 10 10]
#  [ 6  3 10 10 10]
#  [ 1  4  0  9 10]]

# %%
plt.rcParams['figure.figsize'] = (15.0, 15.0)
f, ax = plt.subplots(nrows=1, ncols=10)

for i, j in enumerate(im_samples):
    filename = str(j+1)+'.png'
    fullname = os.path.join('test', filename)
    im = Image.open(fullname)
    house_num = ''
    for k in np.arange(np.sum(test_prediction[i,:] != 10)):
        house_num += str(test_prediction[i,k])

    ax[i].axis('off')
    ax[i].set_title(house_num, loc='center')
    ax[i].imshow(im)
